# %% [markdown]
# <a href="https://colab.research.google.com/github/LuciaKajanova/dspracticum25_flowers_team/blob/simpleTokenizationZakony/SimpleTokenizationMergedZakony.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Transformer
#
# You may want to refer directly to [the git repo](https://github.com/karpathy/ng-video-lecture) instead though.

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters – podrobné s poznámkami

# -----------------------------
# Batch size
batch_size = 16
# Větší batch size pomáhá kompenzovat rychlejší learning_rate a snižuje šum gradientů ale je vypocetne narocenjsí
# -----------------------------
# Block size
block_size = 128
# Zvýšeno z 32, model vidí delší kontext pro lepší souvislost vět
#lepší souvislost textu, ale potenciálně horší tvorba jednotlivých slov
# paměťové nároky rostou kvadraticky s block_size zdvojnásobením block_size paměť cca 4× větší
# -----------------------------
# Počet iterací
max_iters = 5000
# Interval pro evaluaci
eval_interval = 200
# -----------------------------
# Learning rate
learning_rate = 7e-3
# Zvýšeno z 1e-3 rychlejší učení, ale vyšší riziko nestability
# k tomu právě přidán
# dropout 0.2–0.3, větší batch size, early stopping
# -----------------------------
# Zařízení
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# -----------------------------
# je potřeba mít konzistetní mezi ruznymi zemnami parametrů aby se dali proovnavat train a val loss
eval_iters = 200
# -----------------------------
# Embedding size
n_embd = 96
# Ponecháno na původním paměťové nároky rostou kvadraticky s embedding_size
# Kvalita zlepšení není tak znatelná za daň s veliksoti, nevyplatí se zvyšovat příliš
# zachovat menší embedding_size pro udržení rozumné velikosti modelu
# -----------------------------
# Počet hlav v multi-head attention
n_head = 6
# Zvýšeno z 4, model se učí jemnější vzory a vztahy mezi tokeny
# embedding_size necháváme 64, každá hlava má méně kapacity je jakoby „hloupější“
# pomáhá spíše struktuře textu, mírně zhoršuje kvalitu jednotlivých slov (u pravinkcejch textu asi podstatný)
# -----------------------------
# Počet vrstev
n_layer = 6
# Zvýšeno z 4, lepší zachycení souvislostí a struktury textu
# zyvšení paměťových nároků a výpočetní náročnosti
# hledám nějaký kompromis mezi kvalitou generovaného textu a rychlostí tréninku
# -----------------------------
# Dropout
dropout = 0.3
# pro kompenzaci vyšší learning_rate, pomáhá stabilizovat trénink, jeste se prida i early stopping


# for saving the model
import os, json
SAVE_DIR = "./final_model"
MODEL_PATH = os.path.join(SAVE_DIR, "model_final.pt")
META_PATH = os.path.join(SAVE_DIR, "meta.json")
os.makedirs(SAVE_DIR, exist_ok=True)

torch.manual_seed(1337)

# wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# with open('/content/merged_zakony.md', 'r', encoding='utf-8') as f:
#   text = f.read()
                    ################ TAHÁNÍ PŘÍMO Z GITHUBU ################
# !wget -O merged_zakony.md https://raw.githubusercontent.com/LuciaKajanova/dspracticum25_flowers_team/main/merged_zakony.md
with open('merged_zakony.md', 'r', encoding='utf-8') as f:
    text = f.read()
                    ################ TAHÁNÍ PŘÍMO Z GITHUBU ################


################ Přidání tokenizace ################
import tiktoken

encoding = tiktoken.get_encoding("o200k_base")

encode = lambda s: encoding.encode(s)
decode = lambda l: encoding.decode(l)

data = torch.tensor(encode(text), dtype=torch.long)
vocab_size = encoding.n_vocab
################ Přidání tokenizace ################

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


        ##přidání early stoppingu
best_val_loss = float('inf')
patience = 800        # kolik kroků čekat, než se trénink zastaví
patience_counter = 0  # počítadlo iterací bez zlepšení
best_model_state = None

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        #nove
        train_loss = losses['train']
        val_loss = losses['val']
        ######
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

# early stopping: sleduj nejlepší val_loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_state = model.state_dict()  # ulož nejlepší váhy
            patience_counter = 0
        else:
            patience_counter += eval_interval
            if patience_counter >= patience:
                print(f"Early stopping triggered at step {iter}. Best val loss: {best_val_loss:.4f}")
                break

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# po skončení tréninku vrať nejlepší váhy
if best_model_state is not None:
    model.load_state_dict(best_model_state)
    print("Loaded best model weights from training.")

################ upravení generovani textu pro novou tokenizaci ################
# generate from the model
seed_text = "\n"  # nebo jakýkoliv začátek textu, např. "§ 140"
start = torch.tensor([encode(seed_text)], dtype=torch.long, device=device)

# generování textu
generated = m.generate(start, max_new_tokens=500)[0].tolist()
print(decode(generated))
# Out:
# --2025-11-02 11:46:21--  https://raw.githubusercontent.com/LuciaKajanova/dspracticum25_flowers_team/main/merged_zakony.md
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2591753 (2.5M) [text/plain]
# Saving to: ‘merged_zakony.md’
#
# merged_zakony.md    100%[===================>]   2.47M  --.-KB/s    in 0.04s
#
# 2025-11-02 11:46:22 (59.7 MB/s) - ‘merged_zakony.md’ saved [2591753/2591753]
#
# 39.285459 M parameters
# step 0: train loss 12.3928, val loss 12.4211
# step 200: train loss 4.0088, val loss 4.3001
# step 400: train loss 3.5795, val loss 3.9776
# step 600: train loss 3.4113, val loss 3.8245
# step 800: train loss 3.2974, val loss 3.7604
# step 1000: train loss 3.1813, val loss 3.6333
# step 1200: train loss 3.1021, val loss 3.6125
# step 1400: train loss 3.0245, val loss 3.5386
# step 1600: train loss 2.9815, val loss 3.4991
# step 1800: train loss 2.9182, val loss 3.4998
# step 2000: train loss 2.8426, val loss 3.3916
# step 2200: train loss 2.8064, val loss 3.3780
# step 2400: train loss 2.7293, val loss 3.3484
# step 2600: train loss 2.6962, val loss 3.3061
# step 2800: train loss 2.6375, val loss 3.2779
# step 3000: train loss 2.6378, val loss 3.2462
# step 3200: train loss 2.5846, val loss 3.2688
# step 3400: train loss 2.5602, val loss 3.2321
# step 3600: train loss 2.5327, val loss 3.2161
# step 3800: train loss 2.4883, val loss 3.1805
# step 4000: train loss 2.4541, val loss 3.1910
# step 4200: train loss 2.4377, val loss 3.1906
# step 4400: train loss 2.4201, val loss 3.1891
# step 4600: train loss 2.4003, val loss 3.1941
# Early stopping triggered at step 4600. Best val loss: 3.1805
# Loaded best model weights from training.
#
# 237oddíl 1203
# Základ v jiných smluvlastnictvíjej doložkami a nepojistvádí-li se předmět po jejich zdroj pozemek automat­
# ní držitele.
# Příspěch ve zvláštníivotí škol volna. T o službáchal-li některýchžících i užívání podle jiného závazku
# obsahu příjmení na úsilí nebo na odstavce 2. Změřeží-li to některývající ze spoluvníků i tehdy, platí-li podléhá strana oprávnění
# něná zatížena jiného pozemku, jakým stavby bylo vydá staložil.
# (3)   Má-li práva vlastník pozemku stavjáka i stavby stavby nestanovány platí proba, nemůže předmězením pozemku držitelem, voda nebo pro stavbační jistotu lze odváděrechtního kapitálu jiné osoby
# nebodařeníměrolené sousedb užívání sousedovi při pořizování jistiny
# plnosti knížné kupující vlastnictvým držběžívací.
# § 2664
# Vznikatel v nebrání mezi prokými známostatelem.
# (1)   V yhodnocuje-li společenéhokdy, která z projektu prokmenovaného výnos­ |
# | nahradí nebo jeho jiným většímu. moci ztrátírá ohrožující mimořádně ohledny v závislosti na
# podobnosti nebezpečí, ručí-li takové majetku nebo jinak působící
# úplněné povinností a doby. Nejde-li však se podnikatel za vále o odkládání při pořáštění;
# jádá-li ve smlouvě o podnikání vzhledem k odstranění závazních náklady ES zaměstnavatelem,
#  tepla). metod nebo nevznikatel-li se místo zvyšších.
# § 2642
# Je-li nahlížet přiměřeného stání na dorozornil-liPostoupení jaká ani v rozporu­
# nosti natolik, že kolektivní smlouvy odstoupit nebo formalil, ke stranám

# %%
import json

def save_meta():
    meta = {
        "block_size": block_size,
        "n_embd": n_embd,
        "n_head": n_head,
        "n_layer": n_layer,
        "dropout": dropout,
        "vocab_size": encoding.n_vocab,  # počet tokenů z tiktoken
    }
    with open(META_PATH, "w", encoding="utf-8") as f:
        json.dump(meta, f, ensure_ascii=False, indent=2)

save_meta()
torch.save(model.state_dict(), MODEL_PATH)
print(f"Saved final model to {MODEL_PATH} and meta to {META_PATH}")
# Out:
# Saved final model to ./final_model/model_final.pt and meta to ./final_model/meta.json

# %% [markdown]
# ## Using the saved model
#
# The following code recreates the model and reads saved weights.

# %%
# - Assumes you trained & saved with:
#   - MODEL:  ./final_model/model_final.pt
#   - META:   ./final_model/meta.json

import torch
import torch.nn as nn
from torch.nn import functional as F
import os, json

SAVE_DIR = "./final_model"
MODEL_PATH = os.path.join(SAVE_DIR, "model_final.pt")
META_PATH = os.path.join(SAVE_DIR, "meta.json")

device = 'cuda' if torch.cuda.is_available() else 'cpu'

if not (os.path.exists(MODEL_PATH) and os.path.exists(META_PATH)):
    raise FileNotFoundError(f"Missing model or meta file in {SAVE_DIR}")

with open(META_PATH, "r", encoding="utf-8") as f:
    meta = json.load(f)

block_size = meta["block_size"]
n_embd     = meta["n_embd"]
n_head     = meta["n_head"]
n_layer    = meta["n_layer"]
dropout    = meta["dropout"]

import tiktoken

# z předchozího tréninku
# encoding = tiktoken.get_encoding("o200k_base")  # nebo jiný encoding, který jsi použil
vocab_size = encoding.n_vocab  # počet tokenů
encode = encoding.encode
decode = encoding.decode


# ---------- model definition ----------
class Head(nn.Module):
    def __init__(self, head_size):
        super().__init__()
        self.key   = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer("tril", torch.tril(torch.ones(block_size, block_size)))
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x)
        q = self.query(x)
        wei = q @ k.transpose(-2, -1) * C**-0.5
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float("-inf"))
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)
        v = self.value(x)
        out = wei @ v
        return out

class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)
    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    def __init__(self, n_embd_):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd_, 4 * n_embd_),
            nn.ReLU(),
            nn.Linear(4 * n_embd_, n_embd_),
            nn.Dropout(dropout),
        )
    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    def __init__(self, n_embd_, n_head_):
        super().__init__()
        head_size = n_embd_ // n_head_
        self.sa = MultiHeadAttention(n_head_, head_size)
        self.ffwd = FeedFoward(n_embd_)
        self.ln1 = nn.LayerNorm(n_embd_)
        self.ln2 = nn.LayerNorm(n_embd_)
    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

class BigramLanguageModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape
        tok_emb = self.token_embedding_table(idx)
        pos_emb = self.position_embedding_table(torch.arange(T, device=idx.device))
        x = tok_emb + pos_emb
        x = self.blocks(x)
        x = self.ln_f(x)
        logits = self.lm_head(x)
        loss = None
        if targets is not None:
            B, T, C = logits.shape
            loss = F.cross_entropy(logits.view(B*T, C), targets.view(B*T))
        return logits, loss

    @torch.no_grad()
    def generate(self, idx, max_new_tokens):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -block_size:]
            logits, _ = self(idx_cond)
            logits = logits[:, -1, :]
            probs = F.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx

# ---------- load weights ----------
model = BigramLanguageModel().to(device)
state = torch.load(MODEL_PATH, map_location=device)
model.load_state_dict(state)
model.eval()



################ upraveí generate pro generovaní pri nove tokenizaci ################
# ---------- generate ----------
seed_text = "\n"  # you can add a prompt here if you want
###if else neni potreba pro novou tokenizaci s
start = torch.tensor([encode(seed_text)], dtype=torch.long, device=device)

generated = model.generate(start, max_new_tokens=500)[0].tolist()
print(decode(generated))
# Out:
# bo jeho předloženy v zájmu, posouditost změnou.
# § 2219
# V yžadoval-li rozhodne náležitost smlouvy určení o fúzi bez zůstává, nelze zástupitel právo odporovatste ještě před jiného
# rožetí.
# § 2904
# Soud jednání povinnosti vážné následky na úsilí nebo orgánu veřejný podnotí ve veřejném seznamu
# schova ostatnímu, má se za to učinit ani styku přijmezení. Má se závažuje-li posoudí ponechat, že slabší pro tyto­
# hlásitky. Ze ztrátu funkce potvrdil-li se placení ve výši jejich jednotlivých vévo, připomnosti vzniklou na tak
# vyčinnosti dědictví, činí souhrnnývající zAHLA věd internetu.
# (2)   Není-li společenství vlastníků uvedenede dnem 169ika odchyl.
# § 700
# (1)   Nepovolí-li se z dědického práva k dědictvířečiní plnění, ani věřitel
# pý v břetržitých plnění dědického práva vůči druhého v rámci svého dědice, ledaže i přítomný dluh, než tento by se dědictví jiné dlužníkovi
# uzavřek ze zřetele dodání. Neby mu pozůstalosti, může dosudůstává jediné dědice žijítnout dohody právo ztrátě
# platy.
# (3)   Byly-li každý dědice poslední hra dovolat jen na dobu neurčtení
# c)   Co odkazu odčinil-li dědic dědic ručnou, že majetek nemá, nahradí do dvourtí osoba
# osoby. Jižky stane-li však do manželů, může souseda vyslout byla dědictví, ledaže spavil rozhodnut1. Plodnou část pozůstalostech dědiců pro neplatí
# likvidačníku potvrdil.
# T ýká jsou některého ze dědiců zů neohoděného nebo
# případě.

# %%
seed_text = "Zákon č. 246/1992"  # you can add a prompt here if you want
###if else neni potreba pro novou tokenizaci s
start = torch.tensor([encode(seed_text)], dtype=torch.long, device=device)

generated = model.generate(start, max_new_tokens=500)[0].tolist()
print(decode(generated))
# Out:
# Zákon č. 246/1992 Sb., o podnikání základních újmů (insolvenční a další zákony včetně PR VNÍ (znikějších), ve znění pozdějších předpisů, a zákon č. 256/2011 Sb., o změně (notářských zákonů (notářských,
# předpisů, ve znění pozdějších předpisů,
# zákon č. 455/2000 Sb., o finanč ních předměně.
# 72.  Část druhá zákona č. 103/2005 Sb., o změně některých zákonů, ve znění pozdějších předpisů, a zákon č. 21/1994 Sb., o úplnění pozdějším
# znění pozdějších předpisů, příbuzavující na provádění nadační složky,
# d)   upravuje-li emitent odepře rozhoduje čistou republiky |
# | smlouvy |
# | a)  ležitosti se doplňuje ratifikov písm. a nebezpečí |
# | na působnosti dalších zákonné úvěržených noční listiny |
# | b)   odvolaný orgán a lze v hodnotě potrestán odnětím svobody až na dvě léta nebo výjimečným trestinem zpětové  |
# | přesunu skupinění |
# | činnosti. |
# | strana  |
# |  |
# |  |
# |  |
# | Díl 67 |
# | Agent |
# |  |
# | kdo je nedbalosti zaměstnancem při práci |
# |ěrnice Evropského parlamentu a Rady |
# | § 240 |
# | Pokusitků trestného činu zahlaz uloženývajícímu trestních sankcech. |
# | (1)   Soud může teroristvých podmínek stanovit |
# | d)   P stálovává-li zároveň povolené |
# | d)   za krizové organizací vojenských zavaznou omamnéšetření |
# | hrubování terorismu |
# | a terorahradí takové plnění podle (dále jen „polovolené a) v teréně  |
# | trestních sankcí |
# |

# %%
import os
MODEL_PATH = "./final_model/model_final.pt"
print(os.path.getsize(MODEL_PATH) / 1024**2, "MB")
# Out:
# 152.18816661834717 MB
